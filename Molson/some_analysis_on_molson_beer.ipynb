# %%
import pandas as pd

molson_beers = pd.read_csv('molson_beers.csv')

molson_beers = molson_beers.drop(columns=['Unnamed: 0'])

molson_beers
# Out:
#                                           Name  \
# 0                         Blueberry Colorambic
# 1                         Bourbon Barrel Brown
# 2                                  Coffee Sour
# 3                  Colorado Native Amber Lager
# 4                   Colorado Native Double IPL
# ..                                         ...
# 523                          Touch of Grisette
# 524                                  Up-Hi IPA
# 525  Wake-n-Bake Coffee Oatmeal Imperial Stout
# 526                            Watermelon Gose
# 527         White Chocolate Moo-Hoo Milk Stout
#
#                                Type  ABV  Ratings  Average  \
# 0                          Wild Ale  5.7        6     4.33
# 1                          Wild Ale  5.5        2     4.25
# 2                          Wild Ale  5.5        3     4.17
# 3      Lager - American Amber / Red  5.5      259     3.67
# 4    Lager - India Pale Lager (IPL)  8.5        4     4.03
# ..                              ...  ...      ...      ...
# 523          Farmhouse Ale - Saison  4.5        7     3.36
# 524                  IPA - American  5.9     1338     3.88
# 525                 Stout - Oatmeal  9.4     4054     4.30
# 526                     Sour - Gose  4.5      186     3.81
# 527            Stout - Sweet / Milk  7.6      456     3.92
#
#                        Brewery
# 0    AC Golden Brewing Company
# 1    AC Golden Brewing Company
# 2    AC Golden Brewing Company
# 3    AC Golden Brewing Company
# 4    AC Golden Brewing Company
# ..                         ...
# 523      Terrapin Beer Company
# 524      Terrapin Beer Company
# 525      Terrapin Beer Company
# 526      Terrapin Beer Company
# 527      Terrapin Beer Company
#
# [528 rows x 6 columns]

# %%
molson_beers.sort_values(by=['Average'])
# Out:
#                                                   Name  \
# 344                               Blue Moon Double IPA
# 452                       Stash Exotic Hazy Blonde Ale
# 411                                       Bubble Stash
# 151               Kamenitza Fresh Elderberry And Lemon
# 152                         Kamenitza Fresh Grapefruit
# ..                                                 ...
# 271                                     Berliner Weiss
# 308      Tusk & Grain Bourbon Barrel Aged Belgian Quad
# 463                           Barrel Aged Tiramisu-Hoo
# 181                Staropramen Limited Stories Edition
# 333  Blue Moon Barrel Aged Bourbon Breakfast Brown Ale
#
#                            Type    ABV  Ratings  Average  \
# 344              IPA - Imperial   8.50        0     0.00
# 452       Blonde Ale - American   4.50        0     0.00
# 411              IPA - American   0.00        0     0.00
# 151       Lager - European Pale   2.00        0     0.00
# 152       Lager - European Pale   2.00        0     0.00
# ..                          ...    ...      ...      ...
# 271      Sour - Berliner Weisse   3.50        1     4.47
# 308            Quadrupel (Quad)  13.96        7     4.51
# 463   Stout - American Imperial  11.00        1     4.75
# 181  Pilsner - Bohemian / Czech   0.00        1     5.00
# 333        Brown Ale - American  13.20        1     5.00
#
#                                   Brewery
# 344  Coors Brewing Company (Molson-Coors)
# 452                            Hop Valley
# 411                            Hop Valley
# 151                          Kamenitza AD
# 152                          Kamenitza AD
# ..                                    ...
# 271              Saint Archer Brewing Co.
# 308              Saint Archer Brewing Co.
# 463                 Terrapin Beer Company
# 181                  Pivovary Staropramen
# 333  Coors Brewing Company (Molson-Coors)
#
# [528 rows x 6 columns]

# %%
#
# use only 50 or more reviews
#
molson_beers_with_many_reviews = molson_beers.drop(molson_beers[pd.to_numeric(molson_beers.Ratings) < 50].index)

molson_beers_with_many_reviews.sort_values(by=['Average'])
# Out:
#                                           Name                       Type  \
# 390                               Keystone Ice            Lager - Adjunct
# 391                             Keystone Light              Lager - Light
# 394                           Keystone Premium            Lager - Adjunct
# 381                         Coors Light Iced T            Lager - Adjunct
# 221                         Molson Canadian 67              Lager - Light
# ..                                         ...                        ...
# 497                              Moo-HooChiato       Stout - Sweet / Milk
# 525  Wake-n-Bake Coffee Oatmeal Imperial Stout            Stout - Oatmeal
# 470          Cinnamon Roll'd WnB Oatmeal Stout            Stout - Oatmeal
# 310                 Tusk & Grain Coconut Stout  Stout - American Imperial
# 294                                 Mosaic IPA             IPA - Imperial
#
#       ABV  Ratings  Average                               Brewery
# 390   5.9      776     1.65  Coors Brewing Company (Molson-Coors)
# 391   4.1     2129     1.73  Coors Brewing Company (Molson-Coors)
# 394   4.4      158     1.76  Coors Brewing Company (Molson-Coors)
# 381   4.0       54     1.79  Coors Brewing Company (Molson-Coors)
# 221   3.0       64     1.85                   Molson Coors Canada
# ..    ...      ...      ...                                   ...
# 497   8.5      540     4.14                 Terrapin Beer Company
# 525   9.4     4054     4.30                 Terrapin Beer Company
# 470   9.4      771     4.31                 Terrapin Beer Company
# 310  13.4      110     4.32              Saint Archer Brewing Co.
# 294   9.0      358     4.33              Saint Archer Brewing Co.
#
# [145 rows x 6 columns]

# %%
molson_beers_with_many_reviews.loc[molson_beers['Brewery'] == 'Coors Brewing Company (Molson-Coors)'].sort_values(by=['Average'])
# Out:
#                                         Name                            Type  \
# 390                             Keystone Ice                 Lager - Adjunct
# 391                           Keystone Light                   Lager - Light
# 394                         Keystone Premium                 Lager - Adjunct
# 381                       Coors Light Iced T                 Lager - Adjunct
# 379                              Coors Light                   Lager - Light
# 383                      Coors Non-Alcoholic                Low Alcohol Beer
# 382                  Coors Light Summer Brew            Fruit and Field Beer
# 378                         Coors Extra Gold                 Lager - Adjunct
# 376                            Coors Banquet                 Lager - Adjunct
# 387        George Killian's Irish Red (3.2%)                   Lager - Light
# 380                Coors Light Citrus Radler            Fruit and Field Beer
# 365        Blue Moon Spring Blonde Wheat Ale      Wheat Beer - American Pale
# 368                 Blue Moon Tongue Thai-Ed             Herb and Spice Beer
# 359         Blue Moon Rising Moon Spring Ale  Red Ale - American Amber / Red
# 397                  Third Shift Amber Lager    Lager - American Amber / Red
# 332               Blue Moon Agave Nectar Ale      Wheat Beer - American Pale
# 386               George Killian's Irish Red    Lager - American Amber / Red
# 369             Blue Moon Valencia Amber Ale  Red Ale - American Amber / Red
# 339       Blue Moon Caramel Apple Spiced Ale             Herb and Spice Beer
# 337            Blue Moon Blackberry Tart Ale            Fruit and Field Beer
# 363  Blue Moon Short Straw Farmhouse Red Ale          Farmhouse Ale - Saison
# 366             Blue Moon Summer Honey Wheat      Wheat Beer - American Pale
# 360     Blue Moon Rounder Belgian-Style Pale              Pale Ale - Belgian
# 349          Blue Moon Harvest Pumpkin Wheat                    Pumpkin Beer
# 358                      Blue Moon Proximity      Wheat Beer - American Pale
# 345              Blue Moon Farmhouse Red Ale          Farmhouse Ale - Saison
# 347         Blue Moon Gingerbread Spiced Ale             Herb and Spice Beer
# 388             George Killian's Irish Stout               Stout - Irish Dry
# 335             Blue Moon Belgian Table Pils                Lager - American
# 370             Blue Moon Vintage Blonde Ale       Strong Ale - Belgian Pale
# 329                                 Batch 19                 Lager - Adjunct
# 346                Blue Moon First Peach Ale            Brown Ale - American
# 372                      Blue Moon White IPA                  IPA - American
# 336                  Blue Moon Belgian White            Wheat Beer - Witbier
# 364               Blue Moon Spiced Amber Ale  Red Ale - American Amber / Red
# 354                    Blue Moon Mango Wheat            Fruit and Field Beer
# 341          Blue Moon Cinnamon Horchata Ale             Herb and Spice Beer
# 338       Blue Moon Cappuccino Oatmeal Stout                 Stout - Oatmeal
# 350             Blue Moon Iced Coffee Blonde           Blonde Ale - American
#
#      ABV  Ratings  Average                               Brewery
# 390  5.9      776     1.65  Coors Brewing Company (Molson-Coors)
# 391  4.1     2129     1.73  Coors Brewing Company (Molson-Coors)
# 394  4.4      158     1.76  Coors Brewing Company (Molson-Coors)
# 381  4.0       54     1.79  Coors Brewing Company (Molson-Coors)
# 379  4.2     5519     1.99  Coors Brewing Company (Molson-Coors)
# 383  0.5       97     2.14  Coors Brewing Company (Molson-Coors)
# 382  3.9      269     2.43  Coors Brewing Company (Molson-Coors)
# 378  5.0      324     2.58  Coors Brewing Company (Molson-Coors)
# 376  5.0     3176     2.61  Coors Brewing Company (Molson-Coors)
# 387  3.2       79     2.72  Coors Brewing Company (Molson-Coors)
# 380  4.2       70     2.77  Coors Brewing Company (Molson-Coors)
# 365  5.4      406     2.80  Coors Brewing Company (Molson-Coors)
# 368  7.5       94     2.90  Coors Brewing Company (Molson-Coors)
# 359  5.4      351     2.97  Coors Brewing Company (Molson-Coors)
# 397  5.3     1246     3.02  Coors Brewing Company (Molson-Coors)
# 332  5.6      874     3.03  Coors Brewing Company (Molson-Coors)
# 386  4.9     3180     3.06  Coors Brewing Company (Molson-Coors)
# 369  5.9      479     3.07  Coors Brewing Company (Molson-Coors)
# 339  5.8      451     3.08  Coors Brewing Company (Molson-Coors)
# 337  5.8      329     3.09  Coors Brewing Company (Molson-Coors)
# 363  5.4      771     3.12  Coors Brewing Company (Molson-Coors)
# 366  5.2     1197     3.12  Coors Brewing Company (Molson-Coors)
# 360  5.6      809     3.14  Coors Brewing Company (Molson-Coors)
# 349  5.7     2826     3.14  Coors Brewing Company (Molson-Coors)
# 358  8.5       91     3.15  Coors Brewing Company (Molson-Coors)
# 345  5.4      372     3.15  Coors Brewing Company (Molson-Coors)
# 347  5.9      385     3.31  Coors Brewing Company (Molson-Coors)
# 388  4.9      335     3.34  Coors Brewing Company (Molson-Coors)
# 335  4.2      178     3.35  Coors Brewing Company (Molson-Coors)
# 370  8.5       84     3.35  Coors Brewing Company (Molson-Coors)
# 329  5.5     1270     3.36  Coors Brewing Company (Molson-Coors)
# 346  5.6      329     3.40  Coors Brewing Company (Molson-Coors)
# 372  5.9      573     3.41  Coors Brewing Company (Molson-Coors)
# 336  5.4     7559     3.43  Coors Brewing Company (Molson-Coors)
# 364  5.6      214     3.45  Coors Brewing Company (Molson-Coors)
# 354  5.4      230     3.57  Coors Brewing Company (Molson-Coors)
# 341  5.5      733     3.59  Coors Brewing Company (Molson-Coors)
# 338  5.9      340     3.62  Coors Brewing Company (Molson-Coors)
# 350  5.5       82     3.65  Coors Brewing Company (Molson-Coors)

# %%
def get_average_of_breweries(df):
    breweries = df["Brewery"].unique()

    average_rating_for_breweries = []
    for brewery in breweries :
        df_1 = df.loc[molson_beers['Brewery'] == brewery]
        average_rating_for_breweries.append([brewery, df_1['Average'].mean()])

    result = pd.DataFrame(average_rating_for_breweries, columns = ['Brewery', 'Average Rating'])

    return result

# %%
get_average_of_breweries(molson_beers).sort_values(by=['Average Rating'])
# Out:
#                                  Brewery  Average Rating
# 7                           Kamenitza AD        2.300000
# 12                   Apatinska Pivara AD        2.376667
# 1                          Bergenbier SA        2.500000
# 3         Cobra Beer Partnership Limited        2.542500
# 10                   Molson Coors Canada        2.645970
# 2                        Borsodi Brewery        2.706429
# 16                     Hamms Brewing Co.        2.780000
# 14                   Zagrebaèka Pivovara        2.856667
# 15  Coors Brewing Company (Molson-Coors)        2.976389
# 8                       Trebjesa Brewery        2.984286
# 9                   Pivovary Staropramen        3.294545
# 5          Franciscan Well Micro Brewery        3.346250
# 11            Thomas Caffrey Brewing Co.        3.420000
# 17                            Hop Valley        3.594464
# 6               Granville Island Brewery        3.597500
# 13              Saint Archer Brewing Co.        3.630816
# 4       Creemore Springs Brewery Limited        3.652727
# 18                 Terrapin Beer Company        3.740000
# 0              AC Golden Brewing Company        3.873043

# %%
def get_average_of_styles(df):
    styles = df["Type"].unique()

    average_rating_for_styles = []
    for style in styles :
        df_1 = df.loc[molson_beers['Type'] == style]
        average_rating_for_styles.append([style, df_1['Average'].mean()])

    result = pd.DataFrame(average_rating_for_styles, columns = ['Style', 'Average Rating'])

    return result

# %%
get_average_of_styles(molson_beers).sort_values(by=['Average Rating'])
# Out:
#                              Style  Average Rating
# 15                Low Alcohol Beer        2.164444
# 13           Lager - European Pale        2.430000
# 62          Sour - Berliner Weisse        2.506667
# 5                  Lager - Adjunct        2.513556
# 58             Lager - Malt Liquor        2.537500
# ..                             ...             ...
# 0                         Wild Ale        4.108333
# 51  Farmhouse Ale - Bière de Garde        4.190000
# 50       Stout - American Imperial        4.236250
# 36       Wheat Beer - Dunkelweizen        4.250000
# 67                Quadrupel (Quad)        4.510000
#
# [77 rows x 2 columns]

# %%
def sort_popular_beers_from_brewery(df, brewery) :
    df = df.drop(df[pd.to_numeric(df.Ratings) < 50].index)
    
    df = df.loc[df['Brewery'] == brewery]

    return df.sort_values(by=['Average'])

# %%
sort_popular_beers_from_brewery(molson_beers, 'Molson Coors Canada')
# Out:
#                                Name                          Type  ABV  \
# 221              Molson Canadian 67                 Lager - Light  3.0
# 211                  Keystone Lager               Lager - Adjunct  4.9
# 220  Molson Canadian 6.0 Cold Shots               Lager - Adjunct  6.0
# 193                    Carling Beer               Lager - Adjunct  4.0
# 194               Carling Black Ice               Lager - Adjunct  6.1
# 240                        Molson M               Lager - Adjunct  4.9
# 230                      Molson Dry               Lager - Adjunct  5.5
# 195             Carling Black Label               Lager - Adjunct  5.0
# 225             Molson Canadian Ice               Lager - Adjunct  5.5
# 239                      Molson Ice               Lager - Adjunct  5.6
# 227           Molson Canadian Light                 Lager - Light  4.0
# 244                      Molson XXX           Lager - Malt Liquor  7.3
# 238                   Molson Golden              Lager - American  5.0
# 228           Molson Canadian Wheat               Lager - Adjunct  4.5
# 241          Molson OV (Old Vienna)                Lager - Vienna  5.0
# 226           Molson Canadian Lager               Lager - Adjunct  5.0
# 219                   Molson Brador           Lager - Malt Liquor  6.0
# 247               Old Style Pilsner              Pilsner - German  5.0
# 236                   Molson Export         Blonde Ale - American  5.0
# 248                Rickard's Blonde              Pilsner - German  5.0
# 249                  Rickard's Dark              Porter - English  4.8
# 252                   Rickard's Red  Lager - American Amber / Red  5.2
# 255                 Rickard's White          Wheat Beer - Witbier  5.4
#
#      Ratings  Average              Brewery
# 221       64     1.85  Molson Coors Canada
# 211      146     1.88  Molson Coors Canada
# 220       77     2.32  Molson Coors Canada
# 193       87     2.34  Molson Coors Canada
# 194       62     2.40  Molson Coors Canada
# 240       98     2.43  Molson Coors Canada
# 230      173     2.43  Molson Coors Canada
# 195      216     2.44  Molson Coors Canada
# 225       81     2.47  Molson Coors Canada
# 239      517     2.51  Molson Coors Canada
# 227      153     2.52  Molson Coors Canada
# 244      590     2.52  Molson Coors Canada
# 238      675     2.73  Molson Coors Canada
# 228       51     2.75  Molson Coors Canada
# 241       92     2.80  Molson Coors Canada
# 226     1902     2.83  Molson Coors Canada
# 219       61     2.89  Molson Coors Canada
# 247      168     2.90  Molson Coors Canada
# 236      310     2.94  Molson Coors Canada
# 248      123     3.04  Molson Coors Canada
# 249      184     3.08  Molson Coors Canada
# 252      463     3.14  Molson Coors Canada
# 255      266     3.15  Molson Coors Canada

# %%
def sort_popular_beers_from_style(df, style) :
    df = df.drop(df[pd.to_numeric(df.Ratings) < 50].index)
    
    df = df.loc[df['Type'] == style]

    return df.sort_values(by=['Average'])

# %%
sort_popular_beers_from_style(molson_beers, 'Wild Ale')
# Out:
#                      Name      Type  ABV  Ratings  Average  \
# 18  Hidden Barrel Apricot  Wild Ale  5.4       91     4.02
# 19    Hidden Barrel Peche  Wild Ale  5.5      129     4.09
#
#                       Brewery
# 18  AC Golden Brewing Company
# 19  AC Golden Brewing Company
